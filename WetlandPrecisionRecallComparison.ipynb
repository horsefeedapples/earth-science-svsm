# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
dfes = pd.read_csv('RiverRoad_Quan_RF.csv')
dfes
# Out:
#      GRID_ID  qu_dem_MIN  qu_dem_MAX  qu_dem_RANGE  qu_dem_MEAN  qu_dem_STD  \
# 0      AA-10    0.691847    1.731059      1.039212     1.117221    0.202755
# 1      AA-11    0.641888    1.487661      0.845773     1.059745    0.147762
# 2      AA-12    0.770032    1.507396      0.737363     1.176038    0.160304
# 3      AA-13    0.761148    1.413489      0.652341     1.131694    0.115760
# 4      AA-14    0.696000    1.392386      0.696386     1.160470    0.116413
# ...      ...         ...         ...           ...          ...         ...
# 8606    Z-95    0.851000    1.676798      0.825798     1.409729    0.230505
# 8607    Z-96    0.723952    1.662994      0.939042     1.425776    0.219366
# 8608    Z-97    0.836438    1.653542      0.817103     1.452142    0.180319
# 8609    Z-98    0.997941    1.636024      0.638083     1.461971    0.166600
# 8610    Z-99    0.962564    1.649397      0.686833     1.506675    0.148577
#
# ...

# %%
labels = ['Decision Tree with Gini', 'Decision Tree with Entropy', 'Bagging', 'Random Forest', 'Ada Boosting with SAMME.R', 'Ada Boosting with SAMME', 'Gradient Boosting', 'Bagging PCA', 'Extreme Gradient Boosting', 'Light Gradient Boosting', 'LDA', 'QDA', 'KNN', 'Logistic Regression'  ]
nonwetlands = [.8782, .8889, .9169, .9294, .9050, .9031, .9289, .8953, .9381, .9394, .9333, .8974, .8844, .8428 ]
wetlands = [.9064, .9068, .9184, .9116, 0.8629, .8994, .9247, .8788, .9246, .9244, .7561, .7702, .8205, .8159 ]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, nonwetlands, width, label='Non-wetland')
rects2 = ax.bar(x + width/2, wetlands, width, label='Wetland')

ax.set_ylabel('Precision')
ax.set_title('Comparing Models Precision Values for Wetland vs Non-Wetland')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(bbox_to_anchor=(.105,.24), loc="upper left",  bbox_transform=fig.transFigure)

fig.tight_layout()

ax.set_ylim([.40, 1])
plt.setp(ax.xaxis.get_majorticklabels(), rotation=270)
plt.grid(True, alpha=.5)

plt.show()

# %%
labels = ['Decision Tree with Gini', 'Decision Tree with Entropy', 'Bagging', 'Random Forest', 'Ada Boosting with SAMME.R', 'Ada Boosting with SAMME', 'Gradient Boosting', 'Bagging PCA', 'Extreme Gradient Boosting', 'Light Gradient Boosting', 'LDA', 'QDA', 'KNN', 'Logistic Regression']
nonwetlands = [.8324, .8321, .8524, .8375, .8152, .7360, .8639, .7726, .8629, .8623, .4494, .4981, .6377, .6342]
wetlands = [.9336, .9402, .9556, .9634, .9497, .9556, .9620, .9481, .9673, .9680, .9815, .9673, .9521, .9320]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, nonwetlands, width, label='Non-wetland')
rects2 = ax.bar(x + width/2, wetlands, width, label='Wetland')

ax.set_ylabel('Recall')
ax.set_title('Comparing Models Recall Values for Wetland vs Non-Wetland')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(bbox_to_anchor=(.105,.24), loc="upper left",  bbox_transform=fig.transFigure)

fig.tight_layout()

ax.set_ylim([.40, 1])
plt.setp(ax.xaxis.get_majorticklabels(), rotation=270)
plt.grid(True, alpha=.5)

plt.show()

# %%
labels = ['Decision Tree with Gini', 'Decision Tree with Entropy', 'Bagging', 'Random Forest', 'Ada Boosting with SAMME.R', 'Ada Boosting with SAMME', 'Gradient Boosting', 'Bagging PCA', 'Extreme Gradient Boosting', 'Light Gradient Boosting', 'LDA', 'QDA', 'KNN', 'Logistic Regression']
nonwetlands = [.8547, .8595, .8835, .8810, .8569, .8118, .8952, .8294, .8989, .8992, .6067, .6406, .7411, .7238]
wetlands = [.9198, .9232, .9366, .9368, .9238, .9069, .9430, .9121, .9455, .9457, .8542, .8575, .8814, .8700]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, nonwetlands, width, label='Non-wetland')
rects2 = ax.bar(x + width/2, wetlands, width, label='Wetland')

ax.set_ylabel('F1-Scores')
ax.set_title('Comparing Models F1-Scores for Wetland vs Non-Wetland')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(bbox_to_anchor=(.105,.24), loc="upper left",  bbox_transform=fig.transFigure)

fig.tight_layout()

ax.set_ylim([.40, 1])
plt.setp(ax.xaxis.get_majorticklabels(), rotation=270)
plt.grid(True, alpha=.5)

plt.show()
